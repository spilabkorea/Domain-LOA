# %% [markdown]
# # Autoencoder-for-HDFS-Log-Anomaly-Detection
#
# HDFS Log 데이터를 이용하여 Autoencoder Anomaly Detection 진행.
#
# ---

# %%
# import section
from __future__ import print_function
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras.models import  Model
from keras.layers import Dense, Input

import pandas as pd
import os
import numpy as np
import re
from sklearn.utils import shuffle
from collections import OrderedDict

from utils import dataloader
from utils import preprocessing

# %%
# 그래픽 카드 확인
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11248380144062310811
# ]

# %%
struct_log = './data/HDFS_100k.log_structured.csv' # The structured log file
label_file = './data/HDFS_100k.log_anomaly_label.csv' # The anomaly label file

# %%
df = pd.read_csv(struct_log)

# %%
# simple EDA
for i in df.columns:
    print(i)
    print(df[i].unique())
    print(len(df[i].unique()))
    print(' === ')
# Out:
# LineId
# [     1      2      3 ... 104813 104814 104815]
# 104815
#  ===
# Date
# [81109]
# 1
#  ===
# Time
# [203518 203519 203520 ... 210122 210124 210126]
# 1406
#  ===
# Pid
# [143  35 145 147  29  30  31 142  26 144 146 148  19  27  33  34 149  28
#  150 151 152 153 154 155 156 157 158 159 160 161 162 163 164 165 166 167
#  168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185
#  186 187 188 189 190 191 192 193  32 194 195 196 197 198 199 201 202 203
#  204 205 206 207 208 209 210 211 200 212 213 214 215 217 218 216 219 220
#  221 223 224 226 222 227 228 225 229 231 232 233 235 234 237 238  13 249
#  241 251 230 250 255 258 245 252 254 260 259 256 263 266 262 272 273 239
#  275 269 271 278 281 253 283 261 242 287 289 243 246 277 240 293 236 247
#  295 244 288 297 248 264 292 274 294 257 296 267 270 299 303 285 304 306
#  284 276 308 312 313 311 279 282 314 298 268 323 324 290 265 309 310 327
#  280 330 305 300 333 334 316 335 286 338 315 328 291 325 322 302 326 341
#  344 329 347 343 307 301 355 336 352 358 321 331 360 363 339 340 319 361
#  342 346 367 348 369 365 351 354 374 332 320 356 370 318 359 379 317 382
#  377 364 353 366 386 345 349 388 375 393 350 397 372 380 399 337 371 368
#  389 376 384 383 357 387 405 406 396 381 390 409 410 385 362 394 416 378
#  402 419 418 373 407 424 422 426 400 427 392 395 433 401 391 414 413 436
#  417 437 439 411 398 445 404 440 408 425 412 448 415 452 430 421 403 423
#  450 435 456 453 438 457 429 442 461 463 441 446 465 428 466 470 434 451
#  476 431 443 454 420 458 475 478 444 462 464 468 482 485 486 459 460 488
#  489 467 432 490 477 472 495 447 501 471 449 473 484 487 505 455 508 496
#  512 480 497 515 491 521 502 504 479 520 474 469 503 524 498 500 511 510
#  516 481 483 530 506 513 522 535 537 523 493 526 514 518 492 525 538 542
#  544 539 531 551 553 554 494 499 545 517 548 536 507 561 528 533 543 563
#  566 546 557 540 569 570 559 574 519 552 509 555 549 565 567 579 527 556
#  572 529 532 534 560 562 588 541 593 582 584 595 580 575 598 571 587 547
#  558 573 591 594 596 550 600 603 604 606 607 583 608 611 568 599 612 578
#  614 581 616 592 590 585 564 609 613 615 618 622 589  18 619 620 621 576
#  577 602 597 601 632 586 605 631 633 634 637 638 640 628 629 617 643 623
#  624 636 625 610 626 648 639 641 635 644 652 646 655 656 654 647 653 627
#  650 661 662 666 665 668 658 672 663 649 676 642 630 677 680 645 669 679
#  682 664 684 657 673 667 687 685 671 692 691 651 678 695 681 697 699 659
#  686 702 670 690 708 710 698 660 688 700 683 703 696 704 675 694 712 713
#  707 709 674 718 693 711 720 701 714 721 705 715 719 689 750 751 752 783
#  769]
# 595
#  ===
# Level
# ['INFO' 'WARN']
# 2
#  ===
# Component
# ['dfs.DataNode$DataXceiver' 'dfs.FSNamesystem'
#  'dfs.DataNode$PacketResponder' 'dfs.DataNode$DataTransfer' 'dfs.DataNode'
#  'dfs.DataBlockScanner' 'dfs.FSDataset' 'dfs.DataNode$BlockReceiver']
# 8
#  ===
# Content
# ['Receiving block blk_-1608999687919862906 src: /10.250.19.102:54106 dest: /10.250.19.102:50010'
#  'BLOCK* NameSystem.allocateBlock: /mnt/hadoop/mapred/system/job_200811092030_0001/job.jar. blk_-1608999687919862906'
#  'Receiving block blk_-1608999687919862906 src: /10.250.10.6:40524 dest: /10.250.10.6:50010'
#  ... 'Verification succeeded for blk_3733699983655478771'
#  'Verification succeeded for blk_-8738709778586756237'
#  'Verification succeeded for blk_-4904750120810562215']
# 96247
#  ===
# EventId
# ['E5' 'E22' 'E11' 'E9' 'E26' 'E6' 'E16' 'E18' 'E25' 'E3' 'E2' 'E7' 'E10'
#  'E21' 'E13' 'E14' 'E27' 'E8' 'E15']
# 19
#  ===
# EventTemplate
# ['Receiving block <*> src: /<*> dest: /<*>'
#  'BLOCK* NameSystem.allocateBlock:<*>'
#  'PacketResponder <*> for block <*> terminating'
#  'Received block <*> of size <*> from /<*>'
#  'BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>'
#  'Received block <*> src: /<*> dest: /<*> of size <*>'
#  '<*>:Transmitted block <*> to /<*>'
#  '<*> Starting thread to transfer block <*> to <*>'
#  'BLOCK* ask <*> to replicate <*> to datanode(s) <*>'
#  '<*> Served block <*> to /<*>' 'Verification succeeded for <*>'
#  'writeBlock <*> received exception <*>'
#  'PacketResponder <*> <*> Exception <*>' 'Deleting block <*> file <*>'
#  'Receiving empty packet for block <*>'
#  'Exception in receiveBlock for block <*> <*>'
#  'BLOCK* NameSystem.addStoredBlock: Redundant addStoredBlock request received for <*> on <*> size <*>'
#  'PacketResponder <*> for block <*> Interrupted.'
#  'Changing block file offset of block <*> from <*> to <*> meta file offset to <*>']
# 19
#  ===

# %%
from utils import dataloader
from utils.preprocessing import Vectorizer


batch_size = 32
hidden_size = 32
num_directions = 2
topk = 5
train_ratio = 0.2
window_size = 10
epoches = 2
num_workers = 2
device = 0 

(x_train, window_y_train, y_train), (x_test, window_y_test, y_test) = \
dataloader.load_HDFS(struct_log, label_file=label_file, window='session',                                                                                                          window_size=window_size, train_ratio=train_ratio, split_type='uniform')
# Out:
# ====== Input data summary ======
# Loading ./data/HDFS_100k.log_structured.csv
# 62 251
# Slicing 1587 sessions, with window 10
# Slicing done, 8406 windows generated
# Slicing 6353 sessions, with window 10
# Slicing done, 25807 windows generated
# Train: 8406 windows (464/8406 anomaly), 7942/8406 normal
# Test: 25807 windows (842/25807 anomaly), 24965/25807 normal

# %%
feature_extractor = Vectorizer()
train_dataset = feature_extractor.fit_transform(x_train, window_y_train, y_train)
test_dataset = feature_extractor.transform(x_test, window_y_test, y_test)

# %%
train_dataset
# Out:
# {'SessionId': array([   0,    0,    0, ..., 1586, 1586, 1586]),
#  'window_y': array([2, 2, 2, ..., 6, 6, 1]),
#  'y': array([0, 0, 0, ..., 0, 0, 0]),
#  'x': array([[9, 9, 0, ..., 4, 5, 5],
#         [9, 0, 9, ..., 5, 5, 2],
#         [0, 9, 4, ..., 5, 2, 2],
#         ...,
#         [4, 5, 4, ..., 2, 2, 6],
#         [5, 4, 5, ..., 2, 6, 6],
#         [4, 5, 2, ..., 6, 6, 6]])}

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
    filepath='./data/log_model_HDFS.h5',
    monitor='val_loss',
    save_best_only=True
    )
]

# %%
# Create 6 layer model.
input_dim = train_dataset['x'].shape[1]
input = Input(shape=(input_dim, ))
encode = Dense(input_dim//4*3, activation='relu')(input)
encode = Dense(input_dim//4*2, activation='relu')(encode)
encode = Dense(input_dim//4, activation='relu')(encode)
encode = Dense(1, activation='relu')(encode)

decode = Dense(input_dim//4, activation='relu')(encode)
decode = Dense(input_dim//4*2, activation='relu')(decode)
decode = Dense(input_dim//4*3, activation='relu')(decode)
decode = Dense(input_dim, activation='sigmoid')(decode)

autoencoder = Model(input, decode)

autoencoder.summary()

autoencoder.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['accuracy'])

# Train model.
history = autoencoder.fit(train_dataset['x'], train_dataset['x'],
        epochs=50,
        batch_size=32,
        callbacks=callbacks_list,
        validation_data=(test_dataset['x'], test_dataset['x']),
        shuffle=True
        )
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10)]              0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 66
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 4
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 30
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                70
# =================================================================
# Total params: 223
# Trainable params: 223
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 263/263 [==============================] - 1s 4ms/step - loss: 22.2510 - accuracy: 0.2370 - val_loss: 23.3990 - val_accuracy: 0.2387
# Epoch 2/50
# 263/263 [==============================] - 1s 3ms/step - loss: 21.8521 - accuracy: 0.1465 - val_loss: 22.9063 - val_accuracy: 0.0031
# Epoch 3/50
# 263/263 [==============================] - 1s 2ms/step - loss: 21.2829 - accuracy: 0.0175 - val_loss: 22.4685 - val_accuracy: 0.0031
# Epoch 4/50
# 263/263 [==============================] - 1s 2ms/step - loss: 20.7426 - accuracy: 0.0321 - val_loss: 22.0915 - val_accuracy: 0.0024
# Epoch 5/50
# 263/263 [==============================] - 1s 3ms/step - loss: 20.5598 - accuracy: 0.0449 - val_loss: 21.7736 - val_accuracy: 0.0031
# Epoch 6/50
# 263/263 [==============================] - 1s 3ms/step - loss: 20.3206 - accuracy: 0.0218 - val_loss: 21.5089 - val_accuracy: 0.7221
# Epoch 7/50
# 263/263 [==============================] - 1s 2ms/step - loss: 20.1079 - accuracy: 0.3254 - val_loss: 21.2892 - val_accuracy: 0.7221
# Epoch 8/50
# 263/263 [==============================] - 1s 3ms/step - loss: 19.8146 - accuracy: 0.6142 - val_loss: 21.1071 - val_accuracy: 0.7221
# Epoch 9/50
# 263/263 [==============================] - 1s 3ms/step - loss: 19.4220 - accuracy: 0.5988 - val_loss: 20.9555 - val_accuracy: 0.7221
# Epoch 10/50
# 263/263 [==============================] - 1s 2ms/step - loss: 19.3130 - accuracy: 0.5949 - val_loss: 20.8291 - val_accuracy: 0.7221
# Epoch 11/50
# 263/263 [==============================] - 1s 2ms/step - loss: 19.2863 - accuracy: 0.6073 - val_loss: 20.7229 - val_accuracy: 0.7221
# Epoch 12/50
# 263/263 [==============================] - 1s 2ms/step - loss: 19.2097 - accuracy: 0.6113 - val_loss: 20.6332 - val_accuracy: 0.7221
# Epoch 13/50
# 263/263 [==============================] - 1s 2ms/step - loss: 19.1840 - accuracy: 0.6103 - val_loss: 20.5573 - val_accuracy: 0.7221
# Epoch 14/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.9832 - accuracy: 0.6011 - val_loss: 20.4924 - val_accuracy: 0.7221
# Epoch 15/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.9428 - accuracy: 0.6075 - val_loss: 20.4369 - val_accuracy: 0.7221
# Epoch 16/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.9417 - accuracy: 0.5997 - val_loss: 20.3890 - val_accuracy: 0.7221
# Epoch 17/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.8725 - accuracy: 0.6070 - val_loss: 20.3477 - val_accuracy: 0.7221
# Epoch 18/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.7876 - accuracy: 0.6158 - val_loss: 20.3117 - val_accuracy: 0.7221
# Epoch 19/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.7366 - accuracy: 0.6028 - val_loss: 20.2805 - val_accuracy: 0.7221
# Epoch 20/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.7211 - accuracy: 0.6146 - val_loss: 20.2531 - val_accuracy: 0.7221
# Epoch 21/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6110 - accuracy: 0.6021 - val_loss: 20.2292 - val_accuracy: 0.7221
# Epoch 22/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.7478 - accuracy: 0.6064 - val_loss: 20.2081 - val_accuracy: 0.7221
# Epoch 23/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6797 - accuracy: 0.6158 - val_loss: 20.1896 - val_accuracy: 0.7221
# Epoch 24/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.7603 - accuracy: 0.6076 - val_loss: 20.1732 - val_accuracy: 0.7221
# Epoch 25/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.7517 - accuracy: 0.6076 - val_loss: 20.1588 - val_accuracy: 0.7221
# Epoch 26/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.4738 - accuracy: 0.6053 - val_loss: 20.1460 - val_accuracy: 0.7221
# Epoch 27/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.4512 - accuracy: 0.6007 - val_loss: 20.1347 - val_accuracy: 0.7221
# Epoch 28/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6012 - accuracy: 0.6090 - val_loss: 20.1247 - val_accuracy: 0.7221
# Epoch 29/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6796 - accuracy: 0.6115 - val_loss: 20.1157 - val_accuracy: 0.7221
# Epoch 30/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6183 - accuracy: 0.6075 - val_loss: 20.1077 - val_accuracy: 0.7221
# Epoch 31/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6204 - accuracy: 0.6114 - val_loss: 20.1007 - val_accuracy: 0.7221
# Epoch 32/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5952 - accuracy: 0.6001 - val_loss: 20.0944 - val_accuracy: 0.7221
# Epoch 33/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5184 - accuracy: 0.6091 - val_loss: 20.0888 - val_accuracy: 0.7221
# Epoch 34/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6288 - accuracy: 0.6093 - val_loss: 20.0838 - val_accuracy: 0.7221
# Epoch 35/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5896 - accuracy: 0.5997 - val_loss: 20.0793 - val_accuracy: 0.7221
# Epoch 36/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5259 - accuracy: 0.5976 - val_loss: 20.0753 - val_accuracy: 0.7221
# Epoch 37/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5661 - accuracy: 0.6029 - val_loss: 20.0717 - val_accuracy: 0.7221
# Epoch 38/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.4644 - accuracy: 0.5991 - val_loss: 20.0685 - val_accuracy: 0.7221
# Epoch 39/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.6407 - accuracy: 0.6117 - val_loss: 20.0657 - val_accuracy: 0.7221
# Epoch 40/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.4639 - accuracy: 0.6034 - val_loss: 20.0631 - val_accuracy: 0.7221
# Epoch 41/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.6454 - accuracy: 0.6252 - val_loss: 20.0608 - val_accuracy: 0.7221
# Epoch 42/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6465 - accuracy: 0.5988 - val_loss: 20.0588 - val_accuracy: 0.7221
# Epoch 43/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.5253 - accuracy: 0.6025 - val_loss: 20.0570 - val_accuracy: 0.7221
# Epoch 44/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6106 - accuracy: 0.6073 - val_loss: 20.0553 - val_accuracy: 0.7221
# Epoch 45/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.6925 - accuracy: 0.6122 - val_loss: 20.0539 - val_accuracy: 0.7221
# Epoch 46/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5017 - accuracy: 0.6105 - val_loss: 20.0525 - val_accuracy: 0.7221
# Epoch 47/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.6507 - accuracy: 0.6070 - val_loss: 20.0514 - val_accuracy: 0.7221
# Epoch 48/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5811 - accuracy: 0.6052 - val_loss: 20.0503 - val_accuracy: 0.7221
# Epoch 49/50
# 263/263 [==============================] - 1s 2ms/step - loss: 18.5461 - accuracy: 0.6077 - val_loss: 20.0494 - val_accuracy: 0.7221
# Epoch 50/50
# 263/263 [==============================] - 1s 3ms/step - loss: 18.6023 - accuracy: 0.6036 - val_loss: 20.0485 - val_accuracy: 0.7221

# %%
# # Create 3 layer model.
# input_dim = train_dataset['x'].shape[1]
# input = Input(shape=(input_dim, ))
# encode = Dense(input_dim//2, activation='relu')(input)
# encode = Dense(1, activation='relu')(encode)

# decode = Dense(input_dim//2, activation='relu')(encode)
# decode = Dense(input_dim, activation='sigmoid')(decode)

# autoencoder = Model(input, decode)

# autoencoder.summary()

# autoencoder.compile(optimizer='adam',
#             loss='mean_squared_error',
#             metrics=['accuracy'])

# # Train model.
# history = autoencoder.fit(train_dataset['x'], train_dataset['x'],
#         epochs=50,
#         batch_size=32,
#         callbacks=callbacks_list,
#         validation_data=(test_dataset['x'], test_dataset['x']),
#         shuffle=True
#         )

# %%
new_x=test_dataset['x']

predictions = autoencoder.predict(new_x)

# Calculated MSE.
mse = np.mean(np.power(new_x - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse})

# Set threshold at the 99th quartile.
threshold = error_df.quantile(0.99)

error_df.describe()
# Out:
#        reconstruction_error
# count          25807.000000
# mean              20.048513
# std                4.818224
# min                1.798793
# 25%               14.206450
# 50%               20.507830
# 75%               24.507863
# max               46.612145

# %%
error_df.quantile(0.99)
# Out:
# reconstruction_error    26.809252
# Name: 0.99, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Reconstruction error binned and plotted.
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(error_df.reconstruction_error.values, bins=7)
# Out:
# (array([  290.,  7180.,  6797., 11386.,    44.,    76.,    34.]),
#  array([ 1.79879316,  8.20070059, 14.60260801, 21.00451544, 27.40642286,
#         33.80833029, 40.21023772, 46.61214514]),
#  <BarContainer object of 7 artists>)

# %%
threshold = threshold

# Plot reconstruction error vs. the data.
fig, ax = plt.subplots()
ax.plot(error_df.index, error_df.reconstruction_error, marker='o', ms=3.5, linestyle='')
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='threshold')
ax.legend(loc=5)
plt.title("Reconstruction error")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
# Output anomalies.
index_list = []
for index, row in error_df.iterrows():
    if row.reconstruction_error > int(threshold):
        index_list.append(index)

# %%
result = test_dataset['y'][index_list]

# %%
_, (false_value,true_value) = np.unique(result,return_counts=True)

# %%
print(len(result) ,false_value, true_value)
# Out:
# 1073 913 160

# %%
true_value / len(result)
# Out:
# 0.14911463187325255

# %%
true_value
# Out:
# 160

# %% [markdown]
# * 참조 링크
# 1. Autoencoder : https://github.com/zpettry/AI-Autoencoder-for-HTTP-Log-Anomaly-Detection
# 2. Data & preprocess : https://github.com/logpai/loglizer
