# %% [markdown]
# # Autoencoder-for-HTTP-Log-Anomaly-Detection
#
# Syslog 데이터를 이용하여 Autoencoder Anomaly Detection 진행.
#
# ---

# %% [markdown]
# ## Simple EDA

# %%
# 파일 확인
# !ls "./data"
# Out:
# ha2.txt_structured.csv		 LSTM_model_plot.png
# ha2.txt_templates.csv		 model_plot.png
# HDFS_100k.log_anomaly_label.csv  이벤트 목록_waslog1.xls
# HDFS_100k.log_structured.csv	 이벤트 목록_waslog2.xls
# 이벤트 목록_log1.xls		 이벤트 목록_waslog3.xls
# 이벤트 목록_log2.xls		 weblog.csv
# 이벤트 목록_log3.xls

# %%
# import section
from __future__ import print_function
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras.models import  Model, Sequential
from keras.layers import Dense, Input, LSTM ,Embedding , RepeatVector, TimeDistributed
from keras.utils.vis_utils import plot_model
import numpy as np
import pandas as pd

# %% [markdown]
# ## Neural Netowork Autoencoder
# logparser의 LenMa 를 적용한 데이터

# %%
struct_log = './data/ha2.txt_structured.csv' # The structured log file

# %%
df = pd.read_csv(struct_log)

# %%
df
# Out:
#       LineId        date      time               ip  \
# 0          1  2021-01-19  10:30:48    172.30.171.22
# 1          2  2021-01-19  10:30:48    172.30.171.22
# 2          3  2021-01-19  10:30:04  121.135.187.201
# 3          4  2021-01-19  10:30:04  121.135.187.201
# 4          5  2021-01-19  10:30:04  121.135.187.201
# ...      ...         ...       ...              ...
# 9995    9996  2021-01-18  21:42:43    203.225.59.78
# 9996    9997  2021-01-18  21:42:43    203.225.59.78
# 9997    9998  2021-01-18  21:42:43    203.225.59.78
# 9998    9999  2021-01-18  21:42:43    203.225.59.78
# 9999   10000  2021-01-18  21:42:43    203.225.59.78
#
#                                                 Content   EventId  \
# 0     BENIT_Client IP1 : 114.119.158.142, user_no : ...  73aa200a
# 1     BENIT_Client IP2 : 114.119.158.142, user_no : ...  41de2f67
# 2     BENIT_Client IP2 : 203.225.82.146, user_no : n...  c06227d3
# 3     BENIT_Client IP2 : 203.225.82.146, user_no : n...  6d35b111
# 4     BENIT_Client IP1 : 203.225.82.146, user_no : n...  73aa200a
# ...                                                 ...       ...
# 9995  javax.mail.AuthenticationFailedException: AUTH...  9dd86978
# 9996  Caused by: javax.mail.AuthenticationFailedExce...  e7b43955
# 9997  Caused by: javax.mail.AuthenticationFailedExce...  e7b43955
# 9998  com.thinkm.mink.commons.exection.MinkException...  a7e71bf9
# 9999                     java.lang.NullPointerException  e6d8ab55
#
#                                           EventTemplate
# 0     BENIT_Client <*> : <*>, user_no :  session_id ...
# 1     BENIT_Client <*> : <*>, user_no : null, Header...
# 2     BENIT_Client <*> : <*>, user_no : null, Header...
# 3     BENIT_Client <*> : <*>, user_no : null, Header...
# 4     BENIT_Client <*> : <*>, user_no :  session_id ...
# ...                                                 ...
# 9995  javax.mail.AuthenticationFailedException: AUTH...
# 9996  Caused by: javax.mail.AuthenticationFailedExce...
# 9997  Caused by: javax.mail.AuthenticationFailedExce...
# 9998  com.thinkm.mink.commons.exection.MinkException...
# 9999                     java.lang.NullPointerException
#
# [10000 rows x 7 columns]

# %%
# simple EDA
df.isna().sum()
# Out:
# LineId           0
# date             0
# time             0
# ip               0
# Content          0
# EventId          0
# EventTemplate    0
# dtype: int64

# %%
# simple EDA
for i in df.columns:
    print(i)
    print(df[i].unique())
    print(len(df[i].unique()))
    print(' === ')
# Out:
# LineId
# [    1     2     3 ...  9998  9999 10000]
# 10000
#  ===
# date
# ['2021-01-19' '2021-01-18']
# 2
#  ===
# time
# ['10:30:48' '10:30:04' '10:29:57' ... '21:43:05' '21:42:56' '21:42:43']
# 3510
#  ===
# ip
# ['172.30.171.22' '121.135.187.201' '203.225.59.197' '203.225.27.66'
#  '203.225.2.126' '203.225.2.70' '203.225.25.44' '203.225.27.222'
#  '203.225.59.218' '203.225.252.60' '172.30.151.95' '203.225.2.125'
#  '203.225.1.106' '203.225.1.78' '203.225.1.168' '203.225.1.159'
#  '203.225.255.108' '203.225.2.138' '203.225.2.17' '203.225.59.78']
# 20
#  ===
# Content
# ['BENIT_Client IP1 : 114.119.158.142, user_no : null, session_id : uYIYQ_ShY4w8YzbXKQo1Kghyp7WswskiD0aXwY9BKCL9MQRQkwV3!-602321484!1611019842721, is_new : true, create_time : 20210119 10:30:42, last_access_time : 20210119 10:30:42, interval_time : 1800'
#  'BENIT_Client IP2 : 114.119.158.142, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=en,zh;q=0.1, Host=dream.kolon.com, Accept-Encoding=gzip,deflate, X-Forwarded-For=114.119.158.142, X-WebLogic-Force-JVMID=-602321484, User-Agent=Mozilla/5.0 &#40;Linux; Android 7.0;&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Mobile Safari/537.36 &#40;compatible; PetalBot;+https://aspiegel.com/petalbot&#41;, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client IP2 : 203.225.82.146, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Cookie=JSESSIONID_RECRUIT=TaoYQxLGiBKSVAl8Hi04AcVBqJNCXoMIR5Msxbl-THcrDMDtVjrl!-1363466462; SCOUTER=xd0rdpa8m4bb3; SSCSID=MR11&&TaoYQxLGiBKSVAl8Hi04AcVBqJNCXoMIR5Msxbl-THcrDMDtVjrl!-1363466462!1611019784902, Host=dream.kolon.com, Accept-Encoding=gzip,deflate, X-Forwarded-For=203.225.82.146, X-WebLogic-Force-JVMID=-1363466462, User-Agent=Apache-HttpClient/4.5.9 &#40;Java/1.8.0_181&#41;, Connection=Keep-Alive, Accept=text/html, Cache-Control=no-cache}'
#  ...
#  'BENIT_Client IP1 : 203.225.82.146, user_no : null, session_id : pAcVhN2fZ0CJIg4e1Db-cHWTWxbia3y84xWgLi0cb0biWhQY0mk-!-590163827!1610973765023, is_new : true, create_time : 20210118 09:42:45, last_access_time : 20210118 09:42:45, interval_time : 1800'
#  'BENIT_Client IP1 : 211.214.175.240, user_no : null, session_id : HrAVhPgaeNKrrJ_josPRSvQCbwAH3yHfwAyF1J-D5JvqYoEW7iiR!1988588950!1610973771802, is_new : true, create_time : 20210118 09:42:51, last_access_time : 20210118 09:42:51, interval_time : 1800'
#  'BENIT_Client IP2 : 211.214.175.240, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, Sec-Fetch-Site=cross-site, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br, Referer=https://www.work.go.kr/, X-Forwarded-For=211.214.175.240, DNT=1, X-WebLogic-Force-JVMID=1988588950, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}']
# 7614
#  ===
# EventId
# ['73aa200a' '41de2f67' 'c06227d3' '6d35b111' 'c654f7a2' 'ec07185d'
#  '5d618456' '8b21b47a' '201c5f0d' '7695f6e2' '0dab5092' 'abc84bce'
#  '74b21a90' '59eff59d' 'aeeb31c9' '69f67fb6' '40699ec4' '9181ef56'
#  '3c1608e0' '36e5276f' '6b76454e' 'c7168320' '08725c78' 'f1830cc5'
#  'aa64a7eb' 'a90be105' 'd2fb239f' '8ec564b7' '91278416' '6ddf59c1'
#  '435b0243' '64cead18' '64e0e7d2' '1d69dd66' 'a4ed04b9' '084ae349'
#  'bae225c6' '179a0072' '1e9222dc' 'de34e603' '7a343f41' 'aa399298'
#  '63e57912' '5c8938ff' '0849b9c6' '10041acb' '4b059662' '02558bbd'
#  'c4544b47' '0c25ecca' '26f55688' '0e17e8ad' 'aa511345' '6de1172d'
#  '4f2bed7e' 'accc2445' '10d5112e' '6a53fad9' '2f3280de' 'db30395d'
#  'e682b34c' '8c9d303b' '970d24ca' 'd815bb3d' '1b9652c2' 'a4f37009'
#  'e28700de' 'd359f02a' '4b8a9320' '6a047f37' '3af4c687' 'e16f365d'
#  '17ef7de3' '4e0409c7' 'c094eefc' '717ecf93' 'b9a66d2d' 'b3fa577d'
#  '2b741a88' '97b62992' 'b78a214a' 'e3c1968f' '4920086e' '52b8d522'
#  'fffe4e70' '24baf6dd' 'e7434050' 'b83e247e' '616dec5d' 'b1bbc3ee'
#  '8ab6ca76' '49ac089b' '617c5b4c' '02acd1a5' '4bc75bc8' '7c61a293'
#  '362d29de' '592483f3' '66debd6c' 'eabfab86' '8ceaa160' '95ac88c8'
#  'faa47e1d' 'c84b4312' '71afef29' 'c5d7d7bc' 'fdc1f0ac' '4d4a74a8'
#  '3b37b2b6' 'd8282bef' 'be2beac4' '65fb4401' 'c5e227e3' 'da4a63da'
#  'eee4016a' '7befd3d0' '4f3a2938' '8e7a286d' 'fdc61e02' '6b35c97d'
#  'e99d8f61' '40fab3fe' '1c7ab574' '0dd56344' 'eb5e9f42' 'de80e605'
#  'a3520ced' '94689147' '4b8c4b20' '05c35344' 'd89a3c35' '2f39f65c'
#  'cef659ea' '489572b7' 'c715c363' '32c7f241' '989944bc' '6dab0d6f'
#  '3be721fa' 'fbfb7501' '9c44e51f' '87d2300c' '958b191d' '2890227b'
#  'a3d6544e' '6d96a3c6' '3d6156ca' 'e8ac9d9f' '655dd51d' '874632fd'
#  'da7497c3' '8a4755a8' '778c5beb' 'ae9cca79' '1a8cb8ba' 'ebe31dfd'
#  '5f9e78ff' 'a78b8a60' '2078cd18' 'e5d46da3' 'c79f19c2' '96ac7a34'
#  '34219f0e' '81a70014' '88a807ec' '156365aa' 'cdaa71b2' 'b37a97da'
#  '4d37f367' 'f8c4fd26' '5d1804e2' 'acede7b3' 'ba743f0b' '5a5daca2'
#  'a9e2dbb8' '768b9853' '77ee55c7' '085571ee' '38f2a5d4' '4ba81afc'
#  '36954f52' '0a3cd06f' '106b412c' '599e2a23' '9e8d1794' '59fb30b7'
#  '08136221' '641771b2' '5e7391bf' 'b107bc91' 'd14aa914' '5284cf69'
#  'c446c15a' 'bf6f2606' '02b7ec1c' '720058f8' '4d1bf73f' '527aef95'
#  '27f46395' 'd761fe95' '2f13ebda' '7bbf7daa' '28cfcb41' '56b5f625'
#  '2badf5d2' '8b157dd2' '0b6a7e84' 'c37cf85a' 'ae6e3b70' 'c014cce9'
#  '6439952f' '44e4af8c' 'd765175c' 'acc5ae59' '3e017852' '90186898'
#  'e97a2f89' '86c62cca' '18cdb3e6' '5d24d838' 'f5e509ee' '54ca51b6'
#  'bf33a6d5' '64df62ac' 'cb4f4103' '93eeae60' '23a0504c' 'f0ae1fde'
#  '067cdc24' 'a06bb4b0' '86a7f952' '0e67a91d' 'ae3233aa' 'e31e0937'
#  'fcbe3a36' '08f6ca44' '86388d50' 'a5ec8e9c' '301b3362' 'b3f0d2bc'
#  'c2bdccd9' 'e0ca6773' '108f528f' 'f484fbe1' '6e8085bd' '44a34435'
#  '859fec23' '5ce81e59' '428299bb' 'e800f13b' '84bdb98a' 'fc03cdc9'
#  'e885af47' 'affee9e3' 'd6317dc0' '4a67fcca' 'c63124b4' '8d9bde9c'
#  '906d153b' '7b5d7dd1' '4ced6db3' '1af1aa36' 'de2a129b' 'a8c05fee'
#  '05c2f7cb' '49b5a3d3' '9d293337' '73b7233a' 'c2be5224' '3a64d271'
#  '6b49cd98' '3ecdfb77' 'b7365c37' 'e59967c0' '23af3532' '3647ddab'
#  '9fbb0778' '4d024d80' 'cc77022a' '800aa21f' 'dd2f201b' '2d9068e3'
#  '4b870fc0' 'f0303f65' '929de2b9' '480c3542' 'b495775e' 'a4999843'
#  '03e00d85' 'b11dee3c' '417f5b8c' '742b8d67' 'e5f8f5d2' 'fc3a02aa'
#  '6d8f201d' 'e7b43955' 'a7e71bf9' 'e6d8ab55' '9dd86978' '0e9d89aa'
#  '288e1f4b' '113f3a1c' '46c6a6cf' 'f49103e9' 'e111a526' '9939d9bd'
#  'adf9c45a' '1193e509' '0069eb2f' '6a679a73' '5ec1f85b' '343a89f2'
#  'af3b4c55' '1b5e7c02' '820d5d93' 'a82c6755' 'ce25af9d' 'ffcb8a1d'
#  'f9d699a8' 'de3caf15' '244413d3' '74ece391' 'e9717023' '566762b9'
#  'b4077fc9' '2469dd86' '010289b0']
# 327
#  ===
# EventTemplate
# ['BENIT_Client <*> : <*>, user_no :  session_id :  is_new :  create_time :   last_access_time :   interval_time : 1800'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=en,zh;q=0.1, Host=dream.kolon.com, Accept-Encoding=gzip,deflate, X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;Linux; Android 7.0;&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Mobile Safari/537.36 &#40;compatible; PetalBot;+https://aspiegel.com/petalbot&#41;, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,    Host=dream.kolon.com, Accept-Encoding=gzip,deflate, X-Forwarded-For=<*>,  User-Agent=Apache-HttpClient/4.5.9 &#40;Java/1.8.0_181&#41;, Connection=Keep-Alive, Accept=text/html, Cache-Control=no-cache}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Host=dream.kolon.com, Accept-Encoding=gzip,deflate, X-Forwarded-For=<*>,  User-Agent=Apache-HttpClient/4.5.9 &#40;Java/1.8.0_181&#41;, Connection=Keep-Alive, Accept=text/html, Cache-Control=no-cache}'
#  'Time:20<*> <*>  IF '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                        Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                                      X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, '
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                                    '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SCOUTER=z3ur904lfhfqno; WMONID=QV5p3QpjqzC; _ga=GA1.2.77501999.1601352308; SSCSID=MR22&&qeYYQdFT9OF4M4bvmad18tx_AITU35zwEQ7fh5G255oN24EtbFZX!1988588950!1611019702611; JSESSIONID_RECRUIT=qeYYQdFT9OF4M4bvmad18tx_AITU35zwEQ7fh5G255oN24EtbFZX!1988588950; _gid=GA1.2.1917367886.1611019706; _gat=1, Host=dream.kolon.com, X-Requested-With=kr.co.saramin.brandapp, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Linux; Android 11; SM-G988N Build/RP1A.200720.012; wv&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Version/4.0 Chrome/87.0.4280.141 Mobile Safari/537.36 || Android/11/brand/2.8.4, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-User=?1, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobopen/controller/candidate/JobOpen320WebController/view.hr, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                                        X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                                 X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info :                                '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SCOUTER=z3ur904lfhfqno; WMONID=QV5p3QpjqzC; _ga=GA1.2.77501999.1601352308; SSCSID=MR22&&AC-oATHmMKdFnPcGXabKnjpTSZJ_6ypgogCuSAdz2kUTIC_Vt3us!-41027595!1609136419302; JSESSIONID_RECRUIT=AC-oATHmMKdFnPcGXabKnjpTSZJ_6ypgogCuSAdz2kUTIC_Vt3us!-41027595, Host=dream.kolon.com, X-Requested-With=kr.co.saramin.brandapp, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Linux; Android 11; SM-G988N Build/RP1A.200720.012; wv&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Version/4.0 Chrome/87.0.4280.141 Mobile Safari/537.36 || Android/11/brand/2.8.4, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Referer=https://dream.kolon.com/RECRUIT_KOLON/, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-kr,       Host=dream.kolon.com, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;iPhone; CPU iPhone OS  like Mac OS X&#41; AppleWebKit/605.1.15 &#40;KHTML, like Gecko&#41; Version/14.0 Mobile/15E148 Safari/605.1 NAVER&#40;inapp; search;  10.30.1;  Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-kr, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;iPhone; CPU iPhone OS  like Mac OS X&#41; AppleWebKit/605.1.15 &#40;KHTML, like Gecko&#41; Version/14.0 Mobile/15E148 Safari/605.1 NAVER&#40;inapp; search;  10.30.1;  Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                          X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,   '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko, Cookie=SCOUTER=z6moja66kib4qn; .ASPXFORMSAUTH=3E0A01C835F3341E2A17E62245967A4028D01771D6EC7F96DF399939306F62E00605D26BB33F7B102788B5ED4DE481B31014CD8D2D4A1228C4C9A28B179ADA0C4BD99DD4D4BE94BB00D570039B103F377F169CD0; _ga=GA1.2.1908686555.1611019590; _gid=GA1.2.128939832.1611019590; _gat=1; SSCSID=MR12&&5GAYP_o9ktS26BDp0FQBqUEYaphxbzyAxtZXIvCqIQSad0P5Z_Cd!-590163827!1611019582013; JSESSIONID_RECRUIT=5GAYP_o9ktS26BDp0FQBqUEYaphxbzyAxtZXIvCqIQSad0P5Z_Cd!-590163827, Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/4.0 &#40;compatible; MSIE 7.0; Windows NT 10.0; WOW64; Trident/7.0; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 3.0.30729; .NET CLR 3.5.30729&#41;, Connection=Keep-Alive, Accept=image/gif, image/jpeg, image/pjpeg, application/x-ms-application, application/xaml+xml, application/x-ms-xbap, */*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                      Connection=Keep-Alive,       Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko,  Host=dream.kolon.com, Accept-Encoding=gzip, deflate, Referer=https://dream.kolon.com/RECRUIT_KOLON/, X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;Windows; Trident/7.0; rv:11.0; ko&#41; like Gecko, Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,      Host=dream.kolon.com, Sec-Fetch-Site=cross-site, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,  Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko, Cookie=SCOUTER=z6moja66kib4qn; .ASPXFORMSAUTH=3E0A01C835F3341E2A17E62245967A4028D01771D6EC7F96DF399939306F62E00605D26BB33F7B102788B5ED4DE481B31014CD8D2D4A1228C4C9A28B179ADA0C4BD99DD4D4BE94BB00D570039B103F377F169CD0; _ga=GA1.2.1908686555.1611019590; _gid=GA1.2.128939832.1611019590; _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, Referer=https://dream.kolon.com/RECRUIT_KOLON/, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/4.0 &#40;compatible; MSIE 7.0; Windows NT 10.0; WOW64; Trident/7.0; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 3.0.30729; .NET CLR 3.5.30729&#41;, Connection=Keep-Alive, Accept=image/gif, image/jpeg, image/pjpeg, application/x-ms-application, application/xaml+xml, application/x-ms-xbap, */*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                           Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                                     X-Forwarded-For=<*>,   '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :                       Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty,  Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                              '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Host=dream.kolon.com,  User-Agent=Mozilla/5.0 &#40;Windows NT  Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41;     Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document,   Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      _gat=1,          rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30,   Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,      '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      Host=dream.kolon.com,  User-Agent=Mozilla/5.0 &#40;Windows NT  WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30,   Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,     */*, Content-Type=application/x-www-form-urlencoded}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                          Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SCOUTER=x1gi11h0m29un2; _ga=GA1.2.1230900178.1605661558; _gid=GA1.2.928130080.1611018326; _gat=1; SSCSID=MR21&&CRUYO5DyKTWI1Kc8ckpWySgSlYaEvmWMIjWQe8XvrxOR9lFXb6VR!-602321484!1611019292914; JSESSIONID_RECRUIT=CRUYO5DyKTWI1Kc8ckpWySgSlYaEvmWMIjWQe8XvrxOR9lFXb6VR!-602321484, Host=dream.kolon.com, Content-Length=57, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/83.0.4103.106 Whale/<*> Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, Cache-Control=max-age=0, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/main/controller/candidate/MainRecruitWebController/init.hr, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Content-Type=application/x-www-form-urlencoded, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko, Cookie=SCOUTER=x388vqrfeht49u; SSCSID=MR12&&duoTGHAoIURFJYbUAXR4sTKDcWNBwzWRXv158KTWA4MBfJa4UrDb!-590163827!1610933104680; JSESSIONID_RECRUIT=duoTGHAoIURFJYbUAXR4sTKDcWNBwzWRXv158KTWA4MBfJa4UrDb!-590163827, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/5.0 &#40;X11; Linux x86_64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/58.0.3029.110 Safari/537.36, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                      Origin=https://dream.kolon.com, Connection=Keep-Alive, Cache-Control=max-age=0, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,       Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                      AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36, Connection=Keep-Alive,       Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,  Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, image/jxr, */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                                    X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      _gat=1, Host=dream.kolon.com, X-Requested-With=XMLHttpRequest,  Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0           Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp060WebController/searchCandidateMaster.hr, Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                            Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Host=dream.kolon.com, AMP-Cache-Transform=google;v="1..5", Accept-Encoding=gzip,deflate,br, X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;Linux; Android 6.0.1; Nexus 5X Build/MMB29P&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.90 Mobile Safari/537.36 &#40;compatible; Googlebot/2.1; +http://www.google.com/bot.html&#41;, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/signed-exchange;v=b3,application/xml;q=0.9,*/*;q=0.8, From=googlebot&#40;at&#41;googlebot.com}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      Host=dream.kolon.com, X-Requested-With=XMLHttpRequest,  Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0  NT 10.0; Win64;  AppleWebKit/537.36  like   Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  AJAX_REQUEST_HEADER=AJAX_REQUEST_HEADER, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                               Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,   '
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {X-WebLogic-KeepAliveSecs=30,       _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info :      Host=dream.kolon.com,  User-Agent=Mozilla/5.0 &#40;iPhone; CPU iPhone OS 14_3 like Mac OS X&#41; AppleWebKit/605.1.15 &#40;KHTML, like Gecko&#41; Version/14.0 Mobile/15E148 Safari/605.1 NAVER&#40;inapp; search;  10.30.1;  Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-kr, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,     _gat=1, Host=dream.kolon.com, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36 Edg/<*>, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko,en;q=0.9,en-US;q=0.8, Sec-Fetch-User=?1,  Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                         X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,                    '
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {X-WebLogic-KeepAliveSecs=30,        Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4,     GMT, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, sdch, X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;Windows NT 6.1; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/61.0.3163.100 Safari/537.36, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3, Cache-Control=max-age=0}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,        Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,         X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0         Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, image/jxr, */*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :               rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30,   Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,     */*, Content-Type=application/x-www-form-urlencoded}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {X-WebLogic-KeepAliveSecs=30,       _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,                */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,  Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,                */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,  sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com,  sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41;  Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,  Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,       _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>, DNT=1, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/5.0 &#40;Windows NT  WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,       X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,    Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      _gat=1, sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, X-Requested-With=XMLHttpRequest,  Sec-Fetch-Site=same-origin, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                                     X-Forwarded-For=<*>,  '
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                                         X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :       sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, X-Requested-With=XMLHttpRequest,  Sec-Fetch-Site=same-origin, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0  NT 10.0; Win64;  AppleWebKit/537.36  like  Chrome/87.0.4280.141 Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Dest=empty, Sec-Fetch-Mode=cors, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  AJAX_REQUEST_HEADER=AJAX_REQUEST_HEADER, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :                                    Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm&#41;, Connection=Keep-Alive, Accept=*/*, From=bingbot&#40;at&#41;microsoft.com, Pragma=no-cache, Cache-Control=no-cache}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko, Cookie=WEBSITE_LANG=ko, Host=dream.kolon.com, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp050WebController/init.hr?, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,  User-Agent=facebookexternalhit/1.1; kakaotalk-scrap/1.0; +https://devtalk.kakao.com/t/scrap/33984, Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      _gat=1, Host=dream.kolon.com, X-Requested-With=XMLHttpRequest,  Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0             Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty,  Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>,  Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :                       Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  AJAX_REQUEST_HEADER=AJAX_REQUEST_HEADER, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm&#41;, Connection=Keep-Alive, Accept=*/*, Pragma=no-cache, Cache-Control=no-cache}'
#  'BENIT_Client <*> : <*>, user_no : springfever7@naver.com_20090520000217, Header Info : {Cookie=SCOUTER=x7hb46mfenno12; _gid=GA1.2.23087297.1610967256; _ga=GA1.2.1106715514.1610967256; SSCSID=MR12&&NGAYFpZlBzX4-rlRZ7dt1FIm6HP0-CTyjI_jrIQm0acfTxuGgOw1!-590163827!1611016869477; JSESSIONID_RECRUIT=NGAYFpZlBzX4-rlRZ7dt1FIm6HP0-CTyjI_jrIQm0acfTxuGgOw1!-590163827, Host=dream.kolon.com,  User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko,ja;q=0.5,  Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, Accept=text/html, application/xhtml+xml, image/jxr, */*, Content-Type=application/x-www-form-urlencoded}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :       Host=dream.kolon.com,  User-Agent=Mozilla/5.0 &#40;Windows NT  WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30,   Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,     */*, Content-Type=application/x-www-form-urlencoded}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      X-Requested-With=XMLHttpRequest, Host=dream.kolon.com,  User-Agent=Mozilla/5.0  NT 10.0; WOW64; Trident/7.0;  like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30,   Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,  AJAX_REQUEST_HEADER=AJAX_REQUEST_HEADER, Content-Type=application/x-www-form-urlencoded; charset=UTF-8, Accept=text/html, */*; q=0.01}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Cookie=SCOUTER=x4fkj6h4fpuogi; SignOnDefault=201800871; CheckCom=KII; _ga=GA1.2.1327145539.1582445924; ObSSOCookie=Mz2yrEWQfwNbqzoX%2F5xNXe%2FJAHJP1ovEk5QTaVnaGFWvn7WVbS75HgBhFodNgp96f2vQ9ZgknWZgxCzvElus5A3E0CbFyXNUCnHqRqa6BaupRO41tLG%2BNVWOGSMKJjk3jD1sFsBC3t3q%2B06bJlrbg0AZ04rDFw7r2OACG0%2FCjCEEdVb6ETctj3ivZ5VjBeJDa9fJ36KmX9UdFndTAeysOo8hAiyB2BzP4haS%2BQ5MpQiZII1y77thU1gGQptyU1xo9CEiLVEfaMX3JiMd3VsgQEyWLU59iFVjxzyB%2FD1I6uCDzt3qhmmXjFXytBEPshlA%2B3B77lHAYa1ddX6vGpNlHCHAER21CR98u8ospe1i8ui%2Fjfuheyg9SQZfn7Yd0p5mO3srGvzRJ4X09z4ngjVhGfE9ro4C40hEywy0BYgszICa%2BifpHxPJ%2FAYiUPnzkgmGvtxDLkwaGmh0uZGof9VlBJBHYwT0NkX7osg7u6MAxjvkT45xFloWzs21%2B4YqFlQVuoXL%2Fc%2BhA58MwhfEIYXCirM2t73CovdtvXNgia53i49WVSdzeyvrmvfmZ2SVqQvj1qt5wlPzxZXYDwTK%2BxIx%2Fjzx%2F4W0a0Zhl%2Fr0OP6stSfNDNHiSS%2B8d842RpIFhXY9ynlwScfU4aog%2FbpbLZTh65D%2BEnWaoJMdlY8hMvZrU%2Bmh%2FfA28XSANZToDYbFB4J1; ssotoken=...; IkenFormsAuth=D84783D00485DC187C1EEC43C13D0118485EFD13ED56264145C4C10C2216010EBC843BC4C8A7D5F6B4424DBBA35E6CA406D2BEEC1137F36C9A8B90D9B7356402295BB54764EAC5469389A43F7E6A35971274F56E231A85E95D9F703FD8536A21E53718CD; SSOKEY=OUFlRjBSdGFXNEI5MjNaUFlDdjRsdS81V0YvVXZTaUV0RW1xOW5zWEg5THBxZEtPRkV5cEpvL0RJclN3aGlOVA==; APRUI=; LoginCookie=29471636233116365834178837581636367437032947359813065834341136743484583406075844130658343411110737030050452807341788005000503266178807101788071000500734; WMONID=s6sei95OQtc; SSCSID=MR21&&jBUYK3eAxyEMY0f47MmXHtI_yK_mAaxwaU7V5TPLNqTrDlgdNQLs!-602321484!1611018237824; JSESSIONID_RECRUIT=jBUYK3eAxyEMY0f47MmXHtI_yK_mAaxwaU7V5TPLNqTrDlgdNQLs!-602321484, Host=dream.kolon.com, Content-Length=57, User-Agent=Mozilla/4.0 &#40;compatible; MSIE 7.0; Windows NT 10.0; WOW64; Trident/7.0; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 3.0.30729; .NET CLR 3.5.30729&#41;, Connection=Keep-Alive, X-BlueCoat-Via=877cc0a90c72b984, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/main/controller/candidate/MainRecruitWebController/init.hr, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Accept=image/gif, image/jpeg, image/pjpeg, application/x-ms-application, application/xaml+xml, application/x-ms-xbap, */*, Content-Type=application/x-www-form-urlencoded}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Cookie=SCOUTER=x4fkj6h4fpuogi; SignOnDefault=201800871; CheckCom=KII; _ga=GA1.2.1327145539.1582445924; ObSSOCookie=Mz2yrEWQfwNbqzoX%2F5xNXe%2FJAHJP1ovEk5QTaVnaGFWvn7WVbS75HgBhFodNgp96f2vQ9ZgknWZgxCzvElus5A3E0CbFyXNUCnHqRqa6BaupRO41tLG%2BNVWOGSMKJjk3jD1sFsBC3t3q%2B06bJlrbg0AZ04rDFw7r2OACG0%2FCjCEEdVb6ETctj3ivZ5VjBeJDa9fJ36KmX9UdFndTAeysOo8hAiyB2BzP4haS%2BQ5MpQiZII1y77thU1gGQptyU1xo9CEiLVEfaMX3JiMd3VsgQEyWLU59iFVjxzyB%2FD1I6uCDzt3qhmmXjFXytBEPshlA%2B3B77lHAYa1ddX6vGpNlHCHAER21CR98u8ospe1i8ui%2Fjfuheyg9SQZfn7Yd0p5mO3srGvzRJ4X09z4ngjVhGfE9ro4C40hEywy0BYgszICa%2BifpHxPJ%2FAYiUPnzkgmGvtxDLkwaGmh0uZGof9VlBJBHYwT0NkX7osg7u6MAxjvkT45xFloWzs21%2B4YqFlQVuoXL%2Fc%2BhA58MwhfEIYXCirM2t73CovdtvXNgia53i49WVSdzeyvrmvfmZ2SVqQvj1qt5wlPzxZXYDwTK%2BxIx%2Fjzx%2F4W0a0Zhl%2Fr0OP6stSfNDNHiSS%2B8d842RpIFhXY9ynlwScfU4aog%2FbpbLZTh65D%2BEnWaoJMdlY8hMvZrU%2Bmh%2FfA28XSANZToDYbFB4J1; ssotoken=...; IkenFormsAuth=D84783D00485DC187C1EEC43C13D0118485EFD13ED56264145C4C10C2216010EBC843BC4C8A7D5F6B4424DBBA35E6CA406D2BEEC1137F36C9A8B90D9B7356402295BB54764EAC5469389A43F7E6A35971274F56E231A85E95D9F703FD8536A21E53718CD; SSOKEY=OUFlRjBSdGFXNEI5MjNaUFlDdjRsdS81V0YvVXZTaUV0RW1xOW5zWEg5THBxZEtPRkV5cEpvL0RJclN3aGlOVA==; APRUI=; LoginCookie=29471636233116365834178837581636367437032947359813065834341136743484583406075844130658343411110737030050452807341788005000503266178807101788071000500734; WMONID=s6sei95OQtc, Host=dream.kolon.com, User-Agent=Mozilla/4.0 &#40;compatible; MSIE 7.0; Windows NT 10.0; WOW64; Trident/7.0; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 3.0.30729; .NET CLR 3.5.30729&#41;, Connection=Keep-Alive, X-BlueCoat-Via=877cc0a90c72b984, Cache-Control=max-stale=0, Accept-Language=ko, X-WebLogic-KeepAliveSecs=30, Referer=https://dream.kolon.com/RECRUIT_KOLON/, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Accept=image/gif, image/jpeg, image/pjpeg, application/x-ms-application, application/xaml+xml, application/x-ms-xbap, */*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :      sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, X-Requested-With=XMLHttpRequest,  Sec-Fetch-Site=same-origin, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0  NT 10.0; Win64;  AppleWebKit/537.36  like  Chrome/87.0.4280.141 Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Dest=empty, Sec-Fetch-Mode=cors, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  AJAX_REQUEST_HEADER=AJAX_REQUEST_HEADER, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR, Cookie=SSCSID=MR12&&Ct0YJ2SHgoge2QjjtqQRIOxvvs7OB7UN0G3X1Drej8Nwm4b8rY5b!-590163827!1611017970823; JSESSIONID_RECRUIT=Ct0YJ2SHgoge2QjjtqQRIOxvvs7OB7UN0G3X1Drej8Nwm4b8rY5b!-590163827; _ga=GA1.2.351934032.1611017990; _gid=GA1.2.1762874927.1611017990, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/main/controller/candidate/MainRecruitWebController/init.hr?amp;gi_no=29695032&gi_no=29695032, X-Forwarded-For=<*>, DNT=1, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/5.0 &#40;Windows NT 6.3; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, Referer=http://www.jobkorea.co.kr/List_GI/RD_HomePage_Open.asp?gHomePage=https%3A%2F%2Fdream.kolon.com%2FRECRUIT_KOLON%2Fhr%2Frec%2Frecruit%2Fmain%2Fcontroller%2Fcandidate%2FMainRecruitWebController%2Finit.hr%3Famp%3Bgi_no%3D29695032%26amp%3Bgi_no%3D29695032, X-Forwarded-For=<*>, DNT=1, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/5.0 &#40;Windows NT 6.3; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Cookie=SCOUTER=z6m6m772dth402; JSESSIONID_RECRUIT=4YgYJTLOpQJ6LgG6LwEpZQI502U-IUJkNqMZLyypqbVn9fb3wPgM!-1363466462; SSCSID=MR11&&4YgYJTLOpQJ6LgG6LwEpZQI502U-IUJkNqMZLyypqbVn9fb3wPgM!-1363466462!1611017827022, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, compress, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, user-agent=Mozilla/4.0 &#40;compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; InfoPath.2&#41;, Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,    Host=dream.kolon.com, Accept-Encoding=gzip, deflate, compress, X-Forwarded-For=<*>,   &#40;compatible; MSIE  Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; InfoPath.3; .NET4.0E&#41;, Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,     X-Forwarded-For=<*>,   &#40;compatible; MSIE  Windows NT    Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, compress, X-Forwarded-For=<*>,   &#40;compatible; MSIE  Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; InfoPath.3; .NET4.0E&#41;, Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info :        Host=dream.kolon.com,  User-Agent=Mozilla/5.0 &#40;Windows NT  WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,  Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,     */*, Content-Type=application/x-www-form-urlencoded}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SSCSID=MR11&&Hw0YIJ0P3NDZkorA3sfej0oOXvSYbxcMDXdfRnOXszoFBQxMYicX!-1363466462!1611017526543; JSESSIONID_RECRUIT=Hw0YIJ0P3NDZkorA3sfej0oOXvSYbxcMDXdfRnOXszoFBQxMYicX!-1363466462; _ga=GA1.2.760786604.1611017547; _gid=GA1.2.1611143902.1611017547; _gat=1, sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, Sec-Fetch-Site=same-origin, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.88 Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Sec-Fetch-User=?1,  Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {Upgrade-Insecure-Requests=1,                            Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  Content-Type=application/x-www-form-urlencoded, '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :                 AppleWebKit/537.36 &#40;KHTML, like Gecko&#41;    Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30,  Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Accept-Encoding=gzip, deflate, br,  X-Forwarded-For=<*>,  AJAX_REQUEST_HEADER=AJAX_REQUEST_HEADER, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1,                                 '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-IDCRL_ACCEPTED=t, X-WebLogic-KeepAliveSecs=30, Cookie=SCOUTER=x3lp670hv43fg1; _ga=GA1.2.1329996979.1604467131; WMONID=GVYV_4iw175, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, User-Agent=Mozilla/4.0 &#40;compatible; MSIE 7.0; Windows NT 6.2; WOW64; Trident/7.0; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 3.0.30729; .NET CLR 3.5.30729; InfoPath.3; Tablet PC 2.0; ms-office&#41;, Connection=Keep-Alive, Accept=*/*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SCOUTER=z6m03v5e2qfftm; SCOUTER=x6vv3eup7nnn05; _ga=GA1.2.1627318149.1593332594; WMONID=z0Bd6cCrCvo; SSCSID=MR11&&mQAS-O7C1rukH3kp22lS182wLCoESp_VrEopvT9KGzCa4LxWnWbB!-1363466462!1610931039938; JSESSIONID_RECRUIT=mQAS-O7C1rukH3kp22lS182wLCoESp_VrEopvT9KGzCa4LxWnWbB!-1363466462, sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, Sec-Fetch-Site=none, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Host=dream.kolon.com, Accept-Encoding=gzip, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, User-Agent=bitlybot/3.0 &#40;+http://bit.ly/&#41;, Connection=Keep-Alive}'
#  'Time:20<*>  Port:10061 IF '
#  'BENIT_Client <*> : <*>, user_no :  Header Info :    _gat=1;            rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30,   Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,      '
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30,        X-Forwarded-For=<*>,  User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, image/jxr, */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-IDCRL_ACCEPTED=t, Cookie=SCOUTER=x6i2kn1l65if6; SSCSID=MR22&&3RgX-1RwGZ9zYwqOfVM7yamTHg3ZvR6J6O5J8xSyIOOZQpOI_Ac6!1988588950!1611015083120; JSESSIONID_RECRUIT=3RgX-1RwGZ9zYwqOfVM7yamTHg3ZvR6J6O5J8xSyIOOZQpOI_Ac6!1988588950; SCOUTER=x3pcp7868q0nvt; JSESSIONID_RECRUIT=S24X-xfWAvnNqqLdJz5mBrpspzJkIe8LFMClI8h3LiOL_l8MpfoA!-590163827; SSCSID=MR12&&S24X-xfWAvnNqqLdJz5mBrpspzJkIe8LFMClI8h3LiOL_l8MpfoA!-590163827!1611015067606, Host=dream.kolon.com, Accept-Auth=badger,Wlid1.1,Bearer, User-Agent=Microsoft Office Excel 2014, X-Office-Major-Version=16, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Authorization=Bearer, X-MS-CookieUri-Requested=t, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, X-FeatureVersion=1}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=en-KR;q=1, ko-KR;q=0.9, Cookie=WEBSITE_LANG=en, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, User-Agent=facebookexternalhit/1.1; kakaotalk-scrap/1.0; +https://devtalk.kakao.com/t/scrap/33984, Connection=Keep-Alive, Accept=*/*}'
# ...
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,        Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>,               */*}'
#  'BENIT_Client <*> : <*>, user_no : aretenald@naver.com_20210118215614, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko,ja;q=0.5, Cookie=SCOUTER=x24olhslk0jklt; SSCSID=MR22&&LLYVqDzSgQC7K1mh4fjfiJv3HDLNy_LqGOehcLmBiUv09_FVJwzX!1988588950!1610976083154; JSESSIONID_RECRUIT=LLYVqDzSgQC7K1mh4fjfiJv3HDLNy_LqGOehcLmBiUv09_FVJwzX!1988588950; _gid=GA1.2.488524874.1610976088; _ga=GA1.2.1104205892.1610976088; _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; Touch; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, image/jxr, */*}'
#  'BENIT_Client <*> : <*>, user_no : jjsmm1009@naver.com_20210118220242, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SCOUTER=xqkadkf2cjjt3; SSCSID=MR21&&EzwVleM5k0Qi1L9PrUpuiiWSBn0fsVaAG9bO-Nbts-oVUcY5ktqe!-602321484!1610974880569; JSESSIONID_RECRUIT=EzwVleM5k0Qi1L9PrUpuiiWSBn0fsVaAG9bO-Nbts-oVUcY5ktqe!-602321484; _ga=GA1.2.1025604558.1610974884; _gid=GA1.2.1806713627.1610974884; _gat=1, Host=dream.kolon.com, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Macintosh; Intel Mac OS X 10_14_6&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/83.0.4103.106 Whale/<*> Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-User=?1, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/main/controller/candidate/MainRecruitWebController/init.hr, Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'Caused by: javax.mail.AuthenticationFailedException: AUTHENTICATE failed.'
#  "com.thinkm.mink.commons.exection.MinkException:  Can't     [cause:  "
#  'java.lang.NullPointerException'
#  'javax.mail.AuthenticationFailedException: AUTHENTICATE failed.'
#  'BENIT_Client <*> : <*>, user_no : aretenald@naver.com_20210118215614, Header Info : {Cookie=SCOUTER=x24olhslk0jklt; SSCSID=MR22&&LLYVqDzSgQC7K1mh4fjfiJv3HDLNy_LqGOehcLmBiUv09_FVJwzX!1988588950!1610976083154; JSESSIONID_RECRUIT=LLYVqDzSgQC7K1mh4fjfiJv3HDLNy_LqGOehcLmBiUv09_FVJwzX!1988588950; _ga=GA1.2.1104205892.1610976088; _gid=GA1.2.488524874.1610976088; _gat=1, X-Requested-With=XMLHttpRequest, Host=dream.kolon.com, Content-Length=376, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; Touch; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko,ja;q=0.5, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp060WebController/searchCandidateMaster.hr, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, Content-Type=application/x-www-form-urlencoded; charset=UTF-8, Accept=text/html, */*; q=0.01}'
#  'BENIT_Client <*> : <*>, user_no :  Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko,ja;q=0.5, Cookie=SSCSID=MR22&&LLYVqDzSgQC7K1mh4fjfiJv3HDLNy_LqGOehcLmBiUv09_FVJwzX!1988588950!1610976083154; JSESSIONID_RECRUIT=LLYVqDzSgQC7K1mh4fjfiJv3HDLNy_LqGOehcLmBiUv09_FVJwzX!1988588950; _ga=GA1.2.1104205892.1610976088; _gid=GA1.2.488524874.1610976088; _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate,  X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=1988588950, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; Touch; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, image/jxr, */*}'
#  'Caused by: org.apache.catalina.connector.ClientAbortException: java.net.SocketException: Broken pipe'
#  'Caused by: java.net.SocketException: Broken pipe'
#  "[-499] Can't read email from folder INBOX [cause: java.net.SocketException: Broken pipe] [00C223ED38D719CC5499546531B9B3A4][][::][]"
#  "com.thinkm.mink.commons.exection.MinkException: [-499] Can't read email from folder INBOX [cause: java.net.SocketException: Broken pipe]"
#  'java.net.SocketException: Broken pipe [00C223ED38D719CC5499546531B9B3A4][][::][]'
#  'org.apache.catalina.connector.ClientAbortException: java.net.SocketException: Broken pipe'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR, Cookie=SCOUTER=x1vhr8gqk9sq7c; _ga=GA1.2.762829089.1610975970; _gid=GA1.2.470325169.1610975970; _gat=1, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, Referer=https://dream.kolon.com/RECRUIT_KOLON/, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Accept=text/html, application/xhtml+xml, image/jxr, */*}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-kr, Cookie=SCOUTER=z4gju74p3vncvp; _ga=GA1.2.1085381854.1592882069, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, br, Referer=https://dream.kolon.com/RECRUIT_KOLON/, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/5.0 &#40;iPhone; CPU iPhone OS 14_3 like Mac OS X&#41; AppleWebKit/605.1.15 &#40;KHTML, like Gecko&#41; || iOS/14.3/brand/2.8.4, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, Cookie=SCOUTER=x5ffn1drkl03ru; SCOUTER=x1ic7fqlco5ap; _ga=GA1.2.1411065673.1578933477; WMONID=Z_-ecwj4JRW; _gid=GA1.2.575093210.1610975569; SSCSID=MR11&&agIVoElNq2y8Gc4foW9xQ_StXg3wYxQozMkQRrtzlkrqFyEburb2!-1363466462!1610975562061; JSESSIONID_RECRUIT=agIVoElNq2y8Gc4foW9xQ_StXg3wYxQozMkQRrtzlkrqFyEburb2!-1363466462, Host=dream.kolon.com, X-Requested-With=com.nhn.android.search, Content-Length=57, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Linux; Android 8.0.0; SM-A520S Build/R16NW; wv&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Version/4.0 Chrome/80.0.3987.163 Whale/<*> Crosswalk/<*> Mobile Safari/537.36 NAVER&#40;inapp; search; 730; 10.30.1&#41;, Origin=https://dream.kolon.com, Connection=Keep-Alive, Cache-Control=max-age=0, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Dest=document, Sec-Fetch-Mode=navigate, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/main/controller/candidate/MainRecruitWebController/init.hr, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-1363466462, Content-Type=application/x-www-form-urlencoded, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}'
#  'javax.naming.AuthenticationException: [LDAP: error code 49 - 80090308: LdapErr: DSID-0C090453, comment: AcceptSecurityContext error, data 52e, v3839 at com.sun.jndi.ldap.LdapCtx.mapErrorCode(LdapCtx.java:3087)'
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-kr, Cookie=SCOUTER=x3hs7fo4pb5ogl; _ga=GA1.2.430476633.1600772390; WMONID=VdPn6WiecKa, Host=dream.kolon.com, Accept-Encoding=gzip, deflate, br, Referer=https://m.search.naver.com/search.naver?sm=mtb_sug.top&where=m&oquery=db%EA%B7%B8%EB%A3%B9&tqi=hsT5nsprvjsssAR%2Fk4hssssst%2FR-061641&query=%EC%BD%94%EC%98%A4%EB%A1%B1%EA%B7%B8%EB%A3%B9&acq=db%EC%86%90&acq=%EC%BD%94%EC%98%A4%EB%A1%B1&acr=1&qdt=0, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, User-Agent=Mozilla/5.0 &#40;iPhone; CPU iPhone OS 14_3 like Mac OS X&#41; AppleWebKit/605.1.15 &#40;KHTML, like Gecko&#41; Version/14.0 Mobile/15E148 Safari/605.1 NAVER&#40;inapp; search; 598; 10.30.1; XS&#41;, Connection=Keep-Alive, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8}'
#  'BENIT_Client <*> : <*>, user_no : clood335@naver.com_20210116193516, Header Info : {Cookie=SCOUTER=z7ajoeoocmb6ob; _gid=GA1.2.1401439912.1610960402; _ga=GA1.2.643175230.1610960402; _gat=1; SSCSID=MR12&&Al0VnGiVvjEr4RpglLDZ7b-zNrjOQcFproP2OE4t-RpWf5_r3z3B!-590163827!1610975307925; JSESSIONID_RECRUIT=Al0VnGiVvjEr4RpglLDZ7b-zNrjOQcFproP2OE4t-RpWf5_r3z3B!-590163827, Host=dream.kolon.com, Content-Length=31828, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp020WebController/picturePopup.hr?jobopen_id=LS202101150001&jobapp_company_id=LS, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, Accept=text/html, application/xhtml+xml, image/jxr, */*, Content-Type=multipart/form-data; boundary=---------------------------7e53539360724}'
#  'BENIT_Client <*> : <*>, user_no : jiwoon715@naver.com_20210118220537, Header Info : {Cookie=SCOUTER=z2fas7bdojlp6g; SSCSID=MR12&&_lsVmLMIyW5mKHRPC9hoRwg7_mgFLe0W-8t8o5YtjTYVck1IgTlC!-590163827!1610975064840; JSESSIONID_RECRUIT=_lsVmLMIyW5mKHRPC9hoRwg7_mgFLe0W-8t8o5YtjTYVck1IgTlC!-590163827; _gid=GA1.2.1927306325.1610975112; _ga=GA1.2.1437813544.1610975112, Host=dream.kolon.com, Content-Length=12887, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; WOW64; Trident/7.0; rv:11.0&#41; like Gecko, Connection=Keep-Alive, Cache-Control=no-cache, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp020WebController/picturePopup.hr?jobopen_id=KAT202101150001&jobapp_company_id=KAT, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-590163827, Accept=text/html, application/xhtml+xml, image/jxr, */*, Content-Type=multipart/form-data; boundary=---------------------------7e53da271606f0}'
#  "java.io.IOException: Can't decrypt request data. cause: Error decrypting"
#  'Caused by: javax.crypto.BadPaddingException: Given final block not properly padded'
#  'com.thinkm.mink.commons.encryption.EncryptionException: Error decrypting'
#  'BENIT_Client <*> : <*>, user_no : aretenald@naver.com_20210118215614, Header Info : {Cookie=SCOUTER=x1rnr2f775f3a1; SSCSID=MR21&&rrMVj0iHGYcZZ1VhOfwk6QbYqArIrLTE9Qj09LXWLj7OnMHGjpJI!-602321484!1610974447751; JSESSIONID_RECRUIT=rrMVj0iHGYcZZ1VhOfwk6QbYqArIrLTE9Qj09LXWLj7OnMHGjpJI!-602321484; _ga=GA1.2.2062559113.1610974452; _gid=GA1.2.163709525.1610974452; _gat=1, Host=dream.kolon.com, X-Requested-With=XMLHttpRequest, Content-Length=421, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Linux; Android 10; SM-G973N Build/QP1A.190711.020; wv&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Version/4.0 Chrome/87.0.4280.141 Mobile Safari/537.36 INCRUIT&#40;inapp; main; 238; 3.0.60&#41;, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp020WebController/init.hr, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'BENIT_Client <*> : <*>, user_no : jjsmm1009@naver.com_20210118220242, Header Info : {Cookie=SCOUTER=xqkadkf2cjjt3; SSCSID=MR21&&EzwVleM5k0Qi1L9PrUpuiiWSBn0fsVaAG9bO-Nbts-oVUcY5ktqe!-602321484!1610974880569; JSESSIONID_RECRUIT=EzwVleM5k0Qi1L9PrUpuiiWSBn0fsVaAG9bO-Nbts-oVUcY5ktqe!-602321484; _ga=GA1.2.1025604558.1610974884; _gid=GA1.2.1806713627.1610974884; _gat=1, Host=dream.kolon.com, X-Requested-With=XMLHttpRequest, Content-Length=381, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Macintosh; Intel Mac OS X 10_14_6&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/83.0.4103.106 Whale/<*> Safari/537.36, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp010WebController/saveCandidateMaster.hr?, Accept-Encoding=gzip, deflate, br, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  "java.io.IOException: Can't decrypt request data. cause: incorrect header check"
#  'Caused by: javax.mail.MessagingException: connection failure'
#  'javax.mail.MessagingException: connection failure'
#  'BENIT_Client <*> : <*>, user_no : aretenald@naver.com_20210118215614, Header Info : {Cookie=SSCSID=MR21&&rrMVj0iHGYcZZ1VhOfwk6QbYqArIrLTE9Qj09LXWLj7OnMHGjpJI!-602321484!1610974447751; JSESSIONID_RECRUIT=rrMVj0iHGYcZZ1VhOfwk6QbYqArIrLTE9Qj09LXWLj7OnMHGjpJI!-602321484; _ga=GA1.2.2062559113.1610974452; _gid=GA1.2.163709525.1610974452; _gat=1, Host=dream.kolon.com, X-Requested-With=XMLHttpRequest, Content-Length=381, Sec-Fetch-Site=same-origin, User-Agent=Mozilla/5.0 &#40;Linux; Android 10; SM-G973N Build/QP1A.190711.020; wv&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Version/4.0 Chrome/87.0.4280.141 Mobile Safari/537.36 INCRUIT&#40;inapp; main; 238; 3.0.60&#41;, Origin=https://dream.kolon.com, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=cors, Sec-Fetch-Dest=empty, Referer=https://dream.kolon.com/RECRUIT_KOLON/hr/rec/recruit/jobapp/controller/candidate/JobApp010WebController/saveCandidateMaster.hr, Accept-Encoding=gzip, deflate, X-Forwarded-For=<*>, X-WebLogic-Force-JVMID=-602321484, Accept=text/html, */*; q=0.01, Content-Type=application/x-www-form-urlencoded; charset=UTF-8}'
#  'java.io.IOException: No content'
#  'Caused by: java.io.IOException: No content'
#  "com.thinkm.mink.commons.exection.MinkException: [-499] Can't read email from folder INBOX [cause: No content]"
#  'BENIT_Client <*> : <*>, user_no : null, Header Info : {Upgrade-Insecure-Requests=1, sec-ch-ua="Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87", Host=dream.kolon.com, Sec-Fetch-Site=cross-site, sec-ch-ua-mobile=?0, User-Agent=Mozilla/5.0 &#40;Windows NT 10.0; Win64; x64&#41; AppleWebKit/537.36 &#40;KHTML, like Gecko&#41; Chrome/87.0.4280.141 Safari/537.36, Connection=Keep-Alive, X-WebLogic-KeepAliveSecs=30, Accept-Language=ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7, Sec-Fetch-Mode=navigate, Sec-Fetch-Dest=document, Sec-Fetch-User=?1, Accept-Encoding=gzip, deflate, br, Referer=https://www.work.go.kr/, X-Forwarded-For=<*>, DNT=1, X-WebLogic-Force-JVMID=1988588950, Accept=text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9}']
# 327
#  ===

# %% [markdown]
# ### Train

# %%
from utils import dataloader
from utils.preprocessing import Vectorizer_sys


batch_size = 32
hidden_size = 32
num_directions = 2
topk = 5
train_ratio = 0.2
window_size = 10
epoches = 2
num_workers = 2
device = 0 

x_, window_y_ = \
dataloader.load_sys_time(struct_log, window='session', window_size=window_size, train_ratio=train_ratio, split_type='uniform')
# Out:
# ====== Input data summary ======
# Loading ./data/ha2.txt_structured.csv
# Slicing 769 sessions, with window 10
# Slicing done, 4191 windows generated
# Train: windows

# %%
x_.EventSequence[0]
# Out:
# [296, 297, 298, 298, 299, 296, 296, 297, 298, 1]

# %%
window_y_
# Out:
# 0        327
# 1       #Pad
# 2          1
# 3         12
# 4          1
#         ...
# 4186       1
# 4187       5
# 4188       5
# 4189    #Pad
# 4190    #Pad
# Name: Label, Length: 4191, dtype: object

# %%
feature_extractor = Vectorizer_sys()
train_dataset = feature_extractor.fit_transform(x_, window_y_)

# %%
train_dataset
# Out:
# {'SessionId': array([  0,   0,   1, ..., 767, 767, 768]),
#  'window_y': array([ 2,  1,  4, ..., 61,  1,  1]),
#  'x': array([[ 22,  23,  13, ...,  23,  13,   4],
#         [ 23,  13,  13, ...,  13,   4,   2],
#         [  4,  28,  29, ...,  43,   4,  15],
#         ...,
#         [140,   4,  10, ...,  69,   4,  61],
#         [  4,  10, 140, ...,   4,  61,  61],
#         [ 29,  28,   4, ...,   1,   1,   1]])}

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
    filepath='./data/log_model_HDFS.h5'
    )
]

# %%
# NN Autoencoder model.
input_dim = train_dataset['x'].shape[1]
input = Input(shape=(input_dim, ))
encode = Dense(input_dim//3*2, activation='relu')(input)
encode = Dense(input_dim//3, activation='relu')(encode)
encode = Dense(1, activation='relu')(encode)

decode = Dense(input_dim//3, activation='relu')(encode)
decode = Dense(input_dim//3*2, activation='relu')(decode)
decode = Dense(input_dim, activation='sigmoid')(decode)

autoencoder = Model(input, decode)

# %%
plot_model(autoencoder, to_file='./data/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Create 6 layer model.
input_dim = train_dataset['x'].shape[1]
input = Input(shape=(input_dim, ))
encode = Dense(input_dim//3*2, activation='relu')(input)
encode = Dense(input_dim//3, activation='relu')(encode)
encode = Dense(1, activation='relu')(encode)

decode = Dense(input_dim//3, activation='relu')(encode)
decode = Dense(input_dim//3*2, activation='relu')(decode)
decode = Dense(input_dim, activation='sigmoid')(decode)

autoencoder = Model(input, decode)

plot_model(autoencoder, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
autoencoder.summary()

autoencoder.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['accuracy'])

# Train model.
history = autoencoder.fit(train_dataset['x'], train_dataset['x'],
        epochs=100,
        batch_size=32,
        callbacks=callbacks_list,
        shuffle=True
        )

# %% [markdown]
# ### Check the result

# %%
import pandas as pd

# Combined x and x_test.
new_x = train_dataset['x']

predictions = autoencoder.predict(new_x)

# Calculated MSE.
mse = np.mean(np.power(new_x - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse})

# Set threshold at the 99th quartile.
threshold = error_df.quantile(0.99)

error_df.describe()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Reconstruction error binned and plotted.
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(error_df.reconstruction_error.values, bins=7)

# %%
threshold = threshold

# Plot reconstruction error vs. the data.
fig, ax = plt.subplots()
ax.plot(error_df.index, error_df.reconstruction_error, marker='o', ms=3.5, linestyle='')
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='threshold')
ax.legend(loc=5)
plt.title("Reconstruction error")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# Output anomalies.
index_list = []
for index, row in error_df.iterrows():
    if row.reconstruction_error > int(threshold):
        index_list.append(index)

output = []    
for x in index_list:
    output.append(new_x[x])

# %% [markdown]
# ## LSTM Autoencoder

# %%
x = np.expand_dims(train_dataset['x'],axis=1)

# %%
# LSTM Autoencoder
model = Sequential()

# Encoder
model.add(LSTM(8, activation='relu', input_shape=(1,10), return_sequences=True))
model.add(LSTM(4, activation='relu', return_sequences=True))
model.add(LSTM(1, activation='relu', return_sequences=True))
# model.add(RepeatVector(10))

# Decoder
model.add(LSTM(4, activation='relu', return_sequences=True))
model.add(LSTM(8, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(10)))

# %%
plot_model(model, to_file='./data/LSTM_model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(loss='mse', optimizer='adam',metrics=['accuracy'])

# fit
history = model.fit(x, x,
                     epochs=100, batch_size=32)
